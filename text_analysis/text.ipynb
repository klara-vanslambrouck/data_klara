# %%
import spacy
import re
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("script_clean.csv")
df
# Out:
#                                                     text         speaker  \
# 0      There's nothing to tell! He's just some guy I ...   Monica Geller
# 1      C'mon, you're going out with the guy! There's ...  Joey Tribbiani
# 2      All right Joey, be nice. So does he have a hum...   Chandler Bing
# 3                               Wait, does he eat chalk?   Phoebe Buffay
# 4      Just, 'cause, I don't want her to go through w...   Phoebe Buffay
# ...                                                  ...             ...
# 61305                            Oh, it's gonna be okay.   Chandler Bing
# 61306  Do you guys have to go to the new house right ...    Rachel Green
# 61307                                  We got some time.   Monica Geller
# 61308                   Okay, should we get some coffee?    Rachel Green
# 61309                                       Sure. Where?   Chandler Bing
#
#        season  episode  scene  utterance EPISODE_ID
# ...

# %%
text_data = df["text"].dropna().astype(str)
text_data
# Out:
# 0        There's nothing to tell! He's just some guy I ...
# 1        C'mon, you're going out with the guy! There's ...
# 2        All right Joey, be nice. So does he have a hum...
# 3                                 Wait, does he eat chalk?
# 4        Just, 'cause, I don't want her to go through w...
#                                ...
# 61305                              Oh, it's gonna be okay.
# 61306    Do you guys have to go to the new house right ...
# 61307                                    We got some time.
# 61308                     Okay, should we get some coffee?
# 61309                                         Sure. Where?
# Name: text, Length: 61310, dtype: object
